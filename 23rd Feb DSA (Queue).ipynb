# %%
import queue

q= queue.Queue()
q.put(10)
q.put(20)
q.put(30)
s=[]
while not q.empty():
    ele = q.get()
    s.append(ele)
while (len(s)!=0):
    ele=s.pop()
    print(ele)
# Out:
# 30
# 20
# 10

# %%
from queue import Queue
q = Queue()
s = []
q.put(1)
q.put(2)
q.put(3)
q.put(4)
while not q.empty():
    ele = q.get()
    s.append(ele)
while s:
    ele = s.pop()
    print(ele)
# Out:
# 4
# 3
# 2
# 1
